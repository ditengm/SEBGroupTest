# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
# кол-во элементов в массиве
n = random.randint(0, 1000)

# %%
# случайные данные в массиве
data = np.array([random.randint(0, 1000) for _ in range(n)])
len(data)
# Out:
# 657

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Нормализация
x_max = max(data_normalize)
x_min = min(data_normalize)

data_normalize = (data - x_min)/(x_max-x_min)

# %%
fig, ax = plt.subplots()
ax.hist(data_normalize)
# Out:
# (array([65., 66., 75., 78., 51., 74., 59., 70., 58., 61.]),
#  array([0.002002 , 0.1017017, 0.2014014, 0.3011011, 0.4008008, 0.5005005,
#         0.6002002, 0.6998999, 0.7995996, 0.8992993, 0.998999 ]),
#  <BarContainer object of 10 artists>)

# %%
# Матиматическое ожидание
X = sum(data_normalize)/len(data_normalize)
X
# Out:
# 0.48805121712275384

# %%
# Дисперсия 
D = sum(((data_normalize-X)**2))/len(data_normalize)
D
# Out:
# 0.08081269469635555

# %%
# Стандартное отклонение
std = D**0.5
std
# Out:
# 0.28427573708699716

# %%
plt.figure(figsize=(16, 9))
plt.grid()
plt.hist(data_normalize, label="Распределение")
plt.vlines(X, 0, 100, color = 'red', label=f"Матожидание - {round(X, 3)}")
plt.vlines(std, 0, 100, color = 'blue', label=f"Стандартное отклонение - {round(std, 3)}")
plt.legend()
